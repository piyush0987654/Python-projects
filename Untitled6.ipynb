# %%
#BMI calculator
hight = input("enter your hight: ")
h = float(hight)
weight = input("enter your weight: ")
w = int(weight)
bmi = w / (h**2)
bmi1 = int(bmi)
bmi2 = str(bmi1)
print("your BMI is: " + bmi2)

# %%
#left weeks
age = input("enter your age")
years = 90 - int(age)
weeks = int(years)*52
#left = 4000 - int(weeks)
print(f"you have {weeks} weeks left")

# %%
#tip calculator
print("Welcon to tip calculator")
bill = float(input("what was the total bill? $"))
tip = int(input("how much tip would you like to give? 10, 12, or 15? "))
tip1 = tip / 100 * bill + bill
people = int(input("how many people to split the bill? "))
#total =round((tip1 / people), 2)                                          #=33.6
total = "{:.2f}".format(tip1 / people)                                     #=33.60
print(f"each person have a contri of {total}")

# %%
#rolercoster ticket counter with age money verince
hight=int(input("wlcome to rolercostal ride\nenter your hight to conteniued: "))

if hight >=  120:
  print("you can ride the rolercostal")
  age = int(input("enter your age: "))
  if age < 12:
    print("pay $5 for ticket")
  elif age <= 18:
    print("pay $7")
  else:
    print("pay $15 for ticket")
else:
  print("sorry, you can not ride this")

# %%
#(bmi index)

hight = float(input('enter your hight: '))
weight = int(input("enter your weight"))
bmi1 = weight / (hight**2)
bmi = str(bmi1)

if bmi1 <=18.5:
  print("your bmi is " + bmi + ", you are underweight")

elif bmi1 <=25:
  print("your bmi is " + bmi + ", you have normal weight")

elif bmi1 <=30:
  print("your bmi is " + bmi + ", you are slightly overweight")

elif bmi1 <=35:
  print("your bmi is " + bmi + ", you are obese")

else:
  print("your bmi is " + bmi + ", you are clinically abese")

# %%
#rolercoster ticket counter with age money verince (MY)
hight=int(input("wlcome to rolercostal ride\nenter your hight to conteniued: "))

if hight >=  120:
  print("you can ride the rolercostal")
  age = int(input("enter your age: "))

  if age <= 12:
    print("$5 is for chlid")
    price = 5

  elif age <= 18:
    print("$7 is for young")
    price = 7

  else:
    print("$15 is  for adult")
    price = 15

  input("do you want to take pic: ")


  if input == "yes":
    total = int(price)+3
    print(f"pay ${total} for ticket")

  else:
    print(f"your total is ${price}")

else:
  print("sorry, you can not ride this")

# %%
#pizza order
print("Welcome to PATHAK PIZZA FACTORY, what would you like to order")
user = input("for small pizza press - s\nfor medium pizza press - m\nfor large pizza press - l\n")
if user == "s":
  print("you have selected a small pizza\nthere will be $15 for small")
  bill = 5
  addp = input("do you want to add pepperoni for +$2 ")
  if addp == "yes":
    bill +=2

  addc = input("do you want to add extra cheese for +$1 ")
  if addc == "yes":
    bill += 1

elif user == "m":
  print("you have selected a medium pizza\nthere will be $15 for medium")
  bill = 20
  addp = input("do you want to add pepperoni for +$2 ")
  if addp == "yes":
    bill +=3

  addc = input("do you want to add extra cheese for +$1 ")
  if addc == "yes":
    bill += 1

else:
  print("\nyou have selected a large pizza\nthere will be $15 for large")
  bill = 25
  addp = input("\ndo you want to add pepperoni for +$2 ")
  if addp == "yes":
    bill +=3

  addc = input("do you want add to extra cheese for +$1 ")
  if addc == "yes":
    bill += 1

print(f"\nThank you for choosing PATHAK PIZZA FACTORY\nyour final bill is: ${bill}")

# %%
#treasure island game
#''' is use for multiple lines
# \ is use to egnore the symbol
print('''

   ___________________________________________________________________
  / \-----     ---------  -----------     -------------- ------    ---
  \_/_________________________________________________________________/
  |~ ~~ ~~~ ~ ~ ~~~ ~ _____.----------._ ~~~  ~~~~ ~~   ~~  ~~~~~ ~~~|
  |  _   ~~ ~~ __,---'_       "         `. ~~~ _,--.  ~~~~ __,---.  ~|
  | | \___ ~~ /      ( )   "          "   `-.,' (') \~~ ~ (  / _\ \~~|
  |  \    \__/_   __(( _)_      (    "   "     (_\_) \___~ `-.___,'  |
  |~~ \     (  )_(__)_|( ))  "   ))          "   |    "  \ ~~ ~~~ _ ~|
  |  ~ \__ (( _( (  ))  ) _)    ((     \\//    " |   "    \_____,' | |
  |~~ ~   \  ( ))(_)(_)_)|  "    ))    //\\ " __,---._  "  "   "  /~~|
  |    ~~~ |(_ _)| | |   |   "  (   "      ,-'~~~ ~~~ `-.   ___  /~ ~|
  | ~~     |  |  |   |   _,--- ,--. _  "  (~~  ~~~~  ~~~ ) /___\ \~~ |
  |  ~ ~~ /   |      _,----._,'`--'\.`-._  `._~~_~__~_,-'  |H__|  \ ~|
  |~~    / "     _,-' / `\ ,' / _'  \`.---.._          __        " \~|
  | ~~~ / /   .-' , / ' _,'_  -  _ '- _`._ `.`-._    _/- `--.   " " \|
  |  ~ / / _-- `---,~.-' __   --  _,---.  `-._   _,-'- / ` \ \_   " ||
  | ~ | | -- _    /~/  `-_- _  _,' '  \ \_`-._,-'  / --   \  - \_   /|
  |~~ | \ -      /~~| "     ,-'_ /-  `_ ._`._`-...._____...._,--'  /~|
  | ~~\  \_ /   /~~/    ___  `---  ---  - - ' ,--.     ___        |~ |
  |~   \      ,'~~|  " (o o)   "         " " |~~~ \_,-' ~ `.     ,'~~|
  | ~~ ~|__,-'~~~~~\    \"/      "  "   "    /~ ~~   O ~ ~~`-.__/~ ~~|
  |~~~ ~~~  ~~~~~~~~`.______________________/ ~~~    |   ~~~ ~~ ~ ~~~|
  |____~jrei~__~_______~~_~____~~_____~~___~_~~___~\_|_/ ~_____~___~_|
  / \----- ----- ------------  ------- ----- -------  --------  ------
  \_/_________________________________________________________________/

 ''')
print("     Welcome to treasure island.\n Your mission is to find the treasure.")
dision = input('you are at a cross rode. where do you want to go "LEFT" or "RIGHT": ')

if dision == "left":
  left = input('you came to a lake. there is an island in the middle of lake. do you want to "wait" for boat, or you want to "swim" acros: ')

  if left == "wait":
    yellow = input("you finaly arrived at the island, now there are 3 door, one red, one yellow, and one blue, where do you wants to go: ")

    if yellow == "yellow":
      print("Yahoo! you've done it, you found the treasure")

    elif yellow == "red":
      print("you found an empty box, game over")

    elif yellow == "blue":
      print("you enterd in wrong room, game over")

  else:
    print("there are aligators inside the lake, game over")

else:
  print("game over")

# %%
# rock paper game
import random
rock = '''
          _______
      ---'   ____)
            (_____)
            (_____)
            (____)
      ---.__(___)
'''

paper = '''
          _______
      ---'   ____)____
                ______)
                _______)
               _______)
      ---.__________)
'''

scissors = '''
          _______
      ---'   ____)____
                ______)
             __________)
            (____)
      ---.__(___)
'''

inpu = input("      Welcome to Rock Paper and Scissors Game\nChose 'r' for Rock, 'p' for Paper and 's' for Scissors: ")

if inpu == "r":
  print(rock)

elif inpu == "p":
  print(paper)

elif inpu =="s":
  print(scissors)

sign = [rock, paper, scissors]
comp = random.randint(0, 2)
print(("computer chose:\n" + sign[comp]))

if inpu == "r" and comp == 0:
  print("Game draw")

elif inpu == "r" and comp == 1:
  print("Computer wins")

elif inpu == "r" and comp == 2:
  print("You win ")

elif inpu == "p" and comp == 0:
  print("You win")

elif inpu == "p" and comp == 1:
  print("Game draw")

elif inpu == "p" and comp == 2:
  print("computer wins ")

elif inpu == "s" and comp == 0:
  print("Computer wins")

elif inpu == "s" and comp == 1:
  print("You win")

elif inpu == "s" and comp == 2:
  print("Game draw ")

else:
  print("Game error")

# %%
import random

#def guessing_game():
print("Welcome to the Guessing Game!")
print("I'm thinking of a number between 1 and 100.")
secret_number = random.randint(1, 100)
attempts = 0

while True:
  guess = input("Take a guess: ")
  try:
    guess = int(guess)
  except ValueError:
    print("Please enter a valid number.")
    continue

    attempts += 1

if guess < secret_number:
  print("Too low, try again.")

elif guess > secret_number:
  print("Too high, try again.")
else:
  print(f"Congratulations! You've guessed the number {secret_number}!")
  print(f"It took you {attempts} attempts.")
  break

#guessing_game()
